# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("philosopher0808/real-vs-ai-generated-faces-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 7.19G/7.19G [04:12<00:00, 30.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/philosopher0808/real-vs-ai-generated-faces-dataset/versions/1

# %%
path
# Out:
# '/root/.cache/kagglehub/datasets/philosopher0808/real-vs-ai-generated-faces-dataset/versions/1'

# %%
from google.colab import drive
drive.mount('/content/drive')
dst_path = ''
# Out:
# Mounted at /content/drive

# %%
# ===========================
# 1. Imports
# ===========================
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torchvision import models, transforms

from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
# Out:
# /Users/linjheyu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/linjheyu/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import os
import random
import shutil

# ===========================
# Paths
# ===========================
dataset_path = "/Users/linjheyu/Downloads/test/"
classes = {"1": "real", "0": "fake"}  # mapping class label to folder name
max_per_class = 5000  # limit per class
output_base = "sampled_dataset"

# Create output folders
for folder_name in classes.values():
    os.makedirs(os.path.join(output_base, folder_name), exist_ok=True)

# ===========================
# Randomly sample and copy images
# ===========================
for label, folder_name in classes.items():
    src_folder = os.path.join(dataset_path, label)
    all_images = [f for f in os.listdir(src_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Shuffle and take up to max_per_class
    random.shuffle(all_images)
    selected_images = all_images[:max_per_class]

    # Copy to output folder
    for img_name in selected_images:
        src_path = os.path.join(src_folder, img_name)
        dst_path = os.path.join(output_base, folder_name, img_name)
        shutil.copy2(src_path, dst_path)

    print(f"Copied {len(selected_images)} images for class '{label}' -> {folder_name}/")
# Out:
# Copied 5000 images for class '1' -> real/
# Copied 5000 images for class '0' -> fake/
